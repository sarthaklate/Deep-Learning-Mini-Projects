# %%
# import libraries
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Load dataset
data = pd.read_csv('churn_data.csv')
X = data[['Age','Balance','Active']].values
y = data['Churn'].values

# %%
# Model
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=3))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train model
history = model.fit(X, y, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.3500 - loss: 882.7887
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3500 - loss: 862.9515
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.3500 - loss: 843.1559
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.3500 - loss: 823.4017
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.3500 - loss: 803.6909
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.3500 - loss: 784.0236
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.3500 - loss: 764.4000
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.3500 - loss: 744.8207
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3500 - loss: 725.2862
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.3500 - loss: 705.7968
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.3500 - loss: 686.3524
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.3500 - loss: 666.9534
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.3500 - loss: 647.5995
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3500 - loss: 628.2905
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.3500 - loss: 609.0261
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.3500 - loss: 589.8055
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3500 - loss: 570.6287
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.3500 - loss: 551.4944
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.3500 - loss: 532.4017
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.3500 - loss: 513.3491
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.3500 - loss: 494.3355
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.3500 - loss: 476.6855
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.3500 - loss: 462.0212
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3500 - loss: 447.4815
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.3500 - loss: 433.0538
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3500 - loss: 418.7267
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.3500 - loss: 404.4902
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3500 - loss: 390.3347
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.3500 - loss: 376.2524
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3500 - loss: 362.2364
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.3500 - loss: 348.2799
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3500 - loss: 334.3771
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.3500 - loss: 320.5228
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.3500 - loss: 306.7121
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3500 - loss: 292.9408
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3500 - loss: 279.2047
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.3500 - loss: 265.5003
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3500 - loss: 251.8244
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.3500 - loss: 238.1739
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.3500 - loss: 224.5461
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3500 - loss: 210.9380
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.3500 - loss: 197.3475
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3500 - loss: 183.7721
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3500 - loss: 170.2095
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3500 - loss: 156.6580
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.3500 - loss: 143.1152
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3500 - loss: 129.5795
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.3500 - loss: 116.0491
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.3500 - loss: 102.5219
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.3500 - loss: 88.9963

# %%
# Evaluate
loss, accuracy = model.evaluate(X, y)
print("\nModel Accuracy:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.6500 - loss: 239.2747
#
# Model Accuracy: 0.6499999761581421

# %%
# Predictions
predictions = model.predict(X)

print("\n--- Predictions ---")
for i in range(len(predictions)):
    result = "Churn" if predictions[i] > 0.5 else "No Churn"
    print(f"Input: {X[i]} → Prediction: {predictions[i][0]:.2f} → {result}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
#
# --- Predictions ---
# Input: [  22 1500    1] → Prediction: 1.00 → Churn
# Input: [  25 2000    1] → Prediction: 1.00 → Churn
# Input: [  28 3000    1] → Prediction: 1.00 → Churn
# Input: [  30 3500    0] → Prediction: 1.00 → Churn
# Input: [  32 4000    1] → Prediction: 1.00 → Churn
# Input: [  35 4500    0] → Prediction: 1.00 → Churn
# Input: [  38 5000    0] → Prediction: 1.00 → Churn
# Input: [  40 5500    0] → Prediction: 1.00 → Churn
# Input: [  42 6000    1] → Prediction: 1.00 → Churn
# Input: [  45 6500    0] → Prediction: 1.00 → Churn
# Input: [  48 7000    0] → Prediction: 1.00 → Churn
# Input: [  50 7500    0] → Prediction: 1.00 → Churn
# Input: [  52 8000    0] → Prediction: 1.00 → Churn
# Input: [  55 8500    0] → Prediction: 1.00 → Churn
# Input: [  27 2800    1] → Prediction: 1.00 → Churn
# Input: [  29 3200    1] → Prediction: 1.00 → Churn
# Input: [  33 4200    0] → Prediction: 1.00 → Churn
# Input: [  37 4800    0] → Prediction: 1.00 → Churn
# Input: [  41 5800    0] → Prediction: 1.00 → Churn
# Input: [  46 6700    0] → Prediction: 1.00 → Churn
