# %%
# Import libraries
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
import matplotlib.pyplot as plt

predicted = model.predict(X)

plt.plot(y, label='Actual')
plt.plot(predicted, label='Predicted')
plt.legend()
plt.title("Temperature Prediction")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step

# %%
# Load data
data = pd.read_csv('temperature_data.csv')
temps = data['Temp'].values

# %%
# Prepare sequences
X, y = [], []
for i in range(3, len(temps)):
    X.append(temps[i-3:i])
    y.append(temps[i])

X = np.array(X)
y = np.array(y)

X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# Model
model = Sequential()
model.add(LSTM(50, input_shape=(3,1)))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.fit(X, y, epochs=50)
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 1882.7257
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 1879.0432
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 1875.3353
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1871.6027
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 1867.8463
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1864.0663
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 1860.2627
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 1856.4366
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1852.5876
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 1848.7164
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1844.8232
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1840.9087
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 1836.9749
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 1833.0239
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1829.0586
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1825.0819
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 1821.0967
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 1817.1053
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - loss: 1813.1088
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1809.1072
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 1805.0990
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - loss: 1801.0818
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1797.0508
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1793.0006
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1788.9253
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1784.8171
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 1780.6689
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 1776.4729
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 1772.2212
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1767.9061
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 1763.5203
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 1759.0555
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 1754.5048
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1749.8601
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1745.1138
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - loss: 1740.2571
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 1735.2830
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 1730.1835
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 1724.9514
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 1719.5796
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1714.0615
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1708.3898
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 1702.5575
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 1696.5558
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1690.3739
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 1683.9994
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 1677.4181
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 1670.6134
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 1663.5686
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 1656.2672

# %%
import matplotlib.pyplot as plt

predicted = model.predict(X)

plt.plot(y, label='Actual')
plt.plot(predicted, label='Predicted')
plt.legend()
plt.title("Temperature Prediction")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
